# %%
using PyPlot

# %%
include("JuliaDeSVM.jl")
# Out:
# accuracy => 0.9618
# Figure(PyObject <matplotlib.figure.Figure object at 0x11c4ad090>)
# PyObject <matplotlib.text.Text object at 0x11d7f6a10>

# %%
include("JuliaDeSVM_circle.jl")
# Out:
# accuracy => 0.9514
# Figure(PyObject <matplotlib.figure.Figure object at 0x11ce7c6d0>)
# PyObject <matplotlib.text.Text object at 0x11d8ce810>
